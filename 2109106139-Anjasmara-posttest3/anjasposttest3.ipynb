# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# masukkan data

# %%
df = pd.read_csv("all_bikez_curated.csv")
# Out:
# /var/folders/pn/vjrytstn5mxcjjpncf3xtqxc0000gn/T/ipykernel_4796/1340918445.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("all_bikez_curated.csv")

# %%
df.head()
# Out:
#      Brand                Model  Year                   Category  Rating  \
# 0  acabion      da vinci 650-vi  2011  Prototype / concept model     3.2
# 1  acabion              gtbo 55  2007                      Sport     2.6
# 2  acabion  gtbo 600 daytona-vi  2011  Prototype / concept model     3.5
# 3  acabion  gtbo 600 daytona-vi  2021  Prototype / concept model     NaN
# 4  acabion              gtbo 70  2007  Prototype / concept model     3.1
#
#    Displacement (ccm)  Power (hp)  Torque (Nm) Engine cylinder Engine stroke  \
# 0                 NaN       804.0          NaN        Electric      Electric
# 1              1300.0       541.0        420.0    In-line four   four-stroke
# 2                 NaN       536.0          NaN        Electric      Electric
# 3                 NaN       536.0          NaN        Electric      Electric
# 4              1300.0       689.0        490.0    In-line four   four-stroke
#
# ...

# %% [markdown]
# grafik batang

# %%
# Visualisasi Jumlah Sepeda Motor Berdasarkan Merek
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Brand')
plt.title('Jumlah Sepeda Motor Berdasarkan Merek')
plt.xlabel('Merek')
plt.ylabel('Jumlah')
plt.xticks(rotation=90)
plt.show()
plt.show()
##Dari visualisasi ini, kita dapat melihat seberapa banyak sepeda 
##motor yang ada untuk setiap merek. Merek tertentu mungkin lebih dominan dalam dataset ini.

# %% [markdown]
# pie chart

# %%
# Hitung jumlah setiap kategori dalam kolom "jenis_motor"
jenis_motor_counts = df['Brand'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(jenis_motor_counts, labels=jenis_motor_counts.index, autopct='%1.1f%%')
plt.title('Sebaran Jenis Motor')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# heatmap

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Korelasi antar Fitur pada Data Spesifikasi Sepeda Motor")
plt.xlabel("Fitur")
plt.ylabel("Fitur")
plt.show()

# %% [markdown]
# box plot

# %%
# Membuat box plot untuk tahun produksi
plt.figure(figsize=(10, 6))
sns.boxplot(x='Year', data=df)
plt.title('Distribusi Tahun Produksi Motor')
plt.xlabel('Tahun Produksi')
plt.ylabel('Nilai')
plt.show()
# Out:
# /Users/onnyfahrony/Auzan_127/Auzan_127/lib/python3.10/site-packages/seaborn/categorical.py:420: UserWarning: Legend does not support handles for BoxPlotContainer instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   handles, _ = ax.get_legend_handles_labels()
